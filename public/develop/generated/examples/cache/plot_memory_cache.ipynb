# %%
# %matplotlib inline

# %% [markdown]
# # Memory full cache.
#
# This example shows how to manipulate an [MemoryFullCache][gemseo.caches.memory_full_cache.MemoryFullCache] object.

# %%
from __future__ import annotations

from numpy import array

from gemseo.caches.memory_full_cache import MemoryFullCache

# %% [markdown]
# ## Create
#
#
# We can create an instance of the [MemoryFullCache][gemseo.caches.memory_full_cache.MemoryFullCache] class. We can then
# print it, and we can see it is empty.
#
# !!! warning
#
#     The [MemoryFullCache][gemseo.caches.memory_full_cache.MemoryFullCache] relies on some multiprocessing features.
#     When working on Windows, the execution of scripts containing instances of
#     [MemoryFullCache][gemseo.caches.memory_full_cache.MemoryFullCache] must be protected by an
#     `if __name__ == '__main__':` statement.

# %%
cache = MemoryFullCache()
cache

# %% [markdown]
# ## Cache
#
#
# We can manually add data into the cache. However, it has to be noted that
# most of the time a cache is attached to an [Discipline][gemseo.core.discipline.discipline.Discipline]. Then, the
# cache feeding has not to be performed explicitly by the user.

# %%
cache[{"x": array([1.0])}] = ({"y": array([2.0])}, None)
cache[{"x": array([2.0])}] = ({"y": array([3.0])}, None)
cache

# %% [markdown]
# ## Get all data
#
#
# We can now print some information from the cache, such as its length:

# %%
len(cache)

# %% [markdown]
# We can
# also display all the cached data so far.

# %%
list(cache)

# %% [markdown]
# ## Get last cached data
#
#
# The user can access the last entry (inputs or outputs) which have been
# entered in the cache.

# %%
last_entry = cache.last_entry
last_entry.inputs, last_entry.outputs

# %% [markdown]
# ## Clear
#
# The user can clear a cache of all its entries by using the
# [clear()][gemseo.caches.memory_full_cache.MemoryFullCache.clear] method:

# %%
cache.clear()
cache
